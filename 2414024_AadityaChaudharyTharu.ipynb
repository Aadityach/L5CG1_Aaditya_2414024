# %% [markdown]
# <a href="https://colab.research.google.com/github/Aadityach/L5CG1_Aaditya_2414024/blob/main/2414024_AadityaChaudharyTharu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment-1

# %% [markdown]
# # 3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up

# %% [markdown]
# ## Exercises:
# ## 1. Data Exploration and Understanding:
# ## Dataset overview
# ##1. Load the dataset and display the first 10 rows.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset=pd.read_csv('/content/WHR-2024-5CS037.csv')
print("First 10 rows of the dataset:")
dataset.head(10)
# Out:
# First 10 rows of the dataset:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# ## 2. Identify the number of rows and columns in the dataset.

# %%
rows, cols = dataset.shape
print(f"The dataset has {rows} rows and {cols} columns.")
# Out:
# The dataset has 143 rows and 10 columns.

# %% [markdown]
# 3. List all the columns and their data types.

# %%
print("Columns and their data types:")
dataset.dtypes
# Out:
# Columns and their data types:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# • Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.

# %%
mean_score = dataset['score'].mean()
median_score = dataset['score'].median()
std_dev_score = dataset['score'].std()


print(f"Mean Score: {mean_score}")
print(f"Median Score: {median_score}")
print(f"Standard Deviation of Score: {std_dev_score}")
# Out:
# Mean Score: 5.52758041958042
# Median Score: 5.785
# Standard Deviation of Score: 1.1707165099442995

# %% [markdown]
# 2. Identify the country with the highest and lowest happiness scores.

# %%
# # 2. Identify the country with the highest and lowest happiness scores
highest_score_country = dataset.loc[dataset['score'].idxmax(), 'Country name']
lowest_score_country = dataset.loc[dataset['score'].idxmin(), 'Country name']

highest_score = dataset['score'].max()
lowest_score = dataset['score'].min()

# Print the results
print(f"Country with the highest happiness score ({highest_score}): {highest_score_country}")
print(f"Country with the lowest happiness score ({lowest_score}): {lowest_score_country}")
# Out:
# Country with the highest happiness score (7.741): Finland
# Country with the lowest happiness score (1.721): Afghanistan

# %% [markdown]
# • Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
# Check for missing values in the dataset
missing_values = dataset.isnull().sum()

# Display the total count of missing values for each column
print("Missing values in each column:")
missing_values
# Out:
# Missing values in each column:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# • Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
# 1. Filter the dataset to show only countries with a Score greater than 7.5
filtered_dataset = dataset[dataset['score'] > 7.5]

# 2. Sort the filtered dataset by Log GDP per Capita in descending order
sorted_dataset = filtered_dataset.sort_values(by='Log GDP per capita', ascending=False)

# Display the top 10 rows
print("Top 10 rows of the filtered and sorted dataset:")
sorted_dataset.head(10)
# Out:
# Top 10 rows of the filtered and sorted dataset:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %%
# Create a new column called 'Happiness Category'
def categorize_happiness(score):
    if score < 4:
        return 'Low'
    elif 4 <= score <= 6:
        return 'Medium'
    else:
        return 'High'

dataset['Happiness Category'] = dataset['score'].apply(categorize_happiness)

# Display the first few rows to verify the new column
print("Dataset with the new 'Happiness Category' column:")
dataset.head()
# Out:
# Dataset with the new 'Happiness Category' column:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 3                    0.724                         0.838       0.221
# 4                    0.740                         0.641       0.153
#
#    Perceptions of corruption  Dystopia + residual Happiness Category
# 0                      0.546                2.082               High
# ...

# %% [markdown]
# 2. Data Visualizations:
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
# Sort the dataset by 'score' in descending order and select the top 10 happiest countries
top_10_happiest = dataset.sort_values(by='score', ascending=False).head(10)

# Plotting the vertical bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Country name', y='score',hue='score', data=top_10_happiest, palette='coolwarm')  # Updated palette

# Adding titles and labels
plt.title('Top 10 Happiest Countries by Score', fontsize=14)
plt.xlabel('Country Name', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)



# Show the plot
plt.show()

# %% [markdown]
# 2. Data Visualizations:
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
# Sort the dataset by 'score' in ascending order and select the top 10 unhappiest countries
top_10_unhappiest = dataset.sort_values(by='score', ascending=True).head(10)

# Plotting the line chart
plt.figure(figsize=(10, 6))
sns.lineplot(x='Country name', y='score', data=top_10_unhappiest, marker='o', color='red')

# Adding titles and labels
plt.title('Top 10 Unhappiest Countries by Score', fontsize=14)
plt.xlabel('Country Name', fontsize=12)
plt.ylabel('Score', fontsize=12)

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()

# %% [markdown]
# • Plot a histogram for the Score column to show its distribution and also interpret.

# %%
# Plotting the histogram for the 'Score' column
plt.figure(figsize=(10, 6))
sns.histplot(dataset['score'], bins=20, kde=True, color='blue')

# Adding titles and labels
plt.title('Distribution of Happiness Scores', fontsize=14)
plt.xlabel('Happiness Score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
# Plotting the scatter plot between 'Log GDP per capita' and 'Score'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=dataset, color='blue')

# Adding titles and labels
plt.title('Relationship between GDP per Capita and Happiness Score', fontsize=14)
plt.xlabel('Log GDP per Capita', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# # 3.2 Problem - 2 - Some Advance Data Exploration Task:

# %% [markdown]
# ## Task - 1 - Setup Task - Preparing the South-Asia Dataset:
#  1. Define the countries in South Asia with a list for example:
#  south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Srilanka"]
#  2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
#  3. Save the filtered dataframe as separate CSV files for future use.

# %%
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

sac_filtered_dataset = dataset[dataset['Country name'].isin(south_asian_countries)]

sac_filtered_dataset.to_csv('/content/south_asian_filtered.csv', index=False)

# Display the filtered dataset
sac_filtered_dataset
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# # Task - 2 - Composite Score Ranking:

# %% [markdown]
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
# + 0.30 × Healthy Life Expectancy
# 2. Rank the South Asian countries based on the Composite Score in descending order.
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
sac_dataset=pd.read_csv('/content/south_asian_filtered.csv')
sac_dataset
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual Happiness Category
# ...

# %%
sac_dataset['Composite Score'] = (0.40 * sac_dataset['Log GDP per capita'] +
                                   0.30 * sac_dataset['Social support'] +
                                   0.30 * sac_dataset['Healthy life expectancy'])

# Step 2: Rank the countries based on the Composite Score in descending order
sac_dataset['Rank by Composite Score'] = sac_dataset['Composite Score'].rank(ascending=False, method='min')

# Step 3: Sort the dataset by Composite Score in descending order
ranked_sac_dataset = sac_dataset.sort_values(by='Composite Score', ascending=False)

# Display the top 5 countries with their Composite Score and Rank
ranked_sac_dataset[['Country name', 'Composite Score', 'Rank by Composite Score']].head()
# Out:
#   Country name  Composite Score  Rank by Composite Score
# 3    Sri Lanka           1.0739                      1.0
# 0        Nepal           0.8159                      2.0
# 2        India           0.7874                      3.0
# 1     Pakistan           0.7039                      4.0
# 4   Bangladesh           0.6774                      5.0

# %% [markdown]
# 2. Rank the South Asian countries based on the Composite Score in descending order.

# %%
# Step 2: Rank the South Asian countries based on the Composite Score in descending order
sac_dataset['Rank by Composite Score'] = sac_dataset['Composite Score'].rank(ascending=False, method='min')

# Step 3: Sort the dataset by Composite Score in descending order
ranked_sac_dataset = sac_dataset.sort_values(by='Composite Score', ascending=False)

# Step 4: Display the ranked dataset
print(ranked_sac_dataset[['Country name', 'Composite Score', 'Rank by Composite Score']])
# Out:
#   Country name  Composite Score  Rank by Composite Score
# 3    Sri Lanka           1.0739                      1.0
# 0        Nepal           0.8159                      2.0
# 2        India           0.7874                      3.0
# 1     Pakistan           0.7039                      4.0
# 4   Bangladesh           0.6774                      5.0
# 5  Afghanistan           0.3238                      6.0

# %% [markdown]
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score

# %%
sac_dataset['Composite Score'] = (0.40 * sac_dataset['Log GDP per capita'] +
                                   0.30 * sac_dataset['Social support'] +
                                   0.30 * sac_dataset['Healthy life expectancy'])

# Step 2: Rank the countries based on the Composite Score in descending order
sac_dataset['Rank by Composite Score'] = sac_dataset['Composite Score'].rank(ascending=False, method='min')

# Step 3: Sort the dataset by Composite Score in descending order
ranked_sac_dataset = sac_dataset.sort_values(by='Composite Score', ascending=False)

# Display the top 5 countries with their Composite Score and Rank
print(ranked_sac_dataset[['Country name', 'Composite Score', 'Rank by Composite Score']].head())
# Out:
#   Country name  Composite Score  Rank by Composite Score
# 3    Sri Lanka           1.0739                      1.0
# 0        Nepal           0.8159                      2.0
# 2        India           0.7874                      3.0
# 1     Pakistan           0.7039                      4.0
# 4   Bangladesh           0.6774                      5.0

# %% [markdown]
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.

# %%
top_5_countries = ranked_sac_dataset[['Country name', 'Composite Score']].head()

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))
sns.barplot(data=top_5_countries, x='Composite Score', y='Country name', palette='viridis')

# Add labels and title
plt.xlabel('Composite Score')
plt.ylabel('Country')
plt.title('Top 5 South Asian Countries by Composite Score')

# Show the plot
plt.show()
# Out:
# <ipython-input-18-7d44acb76cc5>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_5_countries, x='Composite Score', y='Country name', palette='viridis')

# %% [markdown]
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %% [markdown]
# After viewing the plots, you can compare the rankings and discuss:
#
# Alignment of Ranks: Do the countries with the highest composite scores also have the highest individual scores for Log GDP per capita, Social support, and Healthy life expectancy?
# Influence of Weights: The Composite Score is a weighted combination of the individual scores. Countries may have a high rank in the composite score even if they aren't the best in all categories (e.g., a country with high GDP but lower life expectancy might still rank high).
# Outliers and Trends: Are there any countries that rank high on individual scores but fall in the rankings due to the influence of other factors?

# %%
# Select the top 5 countries for visualization
top_5_countries = ranked_sac_dataset[['Country name', 'Log GDP per capita',
                                      'Social support', 'Healthy life expectancy', 'Composite Score']].head()

# Create a 2x2 grid for subplots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Plot for Log GDP per capita
sns.barplot(data=top_5_countries, x='Log GDP per capita', y='Country name', ax=axes[0, 0], palette='Blues')
axes[0, 0].set_title('Log GDP per capita')

# Plot for Social Support
sns.barplot(data=top_5_countries, x='Social support', y='Country name', ax=axes[0, 1], palette='Oranges')
axes[0, 1].set_title('Social support')

# Plot for Healthy Life Expectancy
sns.barplot(data=top_5_countries, x='Healthy life expectancy', y='Country name', ax=axes[1, 0], palette='Greens')
axes[1, 0].set_title('Healthy life expectancy')

# Plot for Composite Score
sns.barplot(data=top_5_countries, x='Composite Score', y='Country name', ax=axes[1, 1], palette='Purples')
axes[1, 1].set_title('Composite Score')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# <ipython-input-19-6a2035abc90a>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_5_countries, x='Log GDP per capita', y='Country name', ax=axes[0, 0], palette='Blues')
# <ipython-input-19-6a2035abc90a>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_5_countries, x='Social support', y='Country name', ax=axes[0, 1], palette='Oranges')
# <ipython-input-19-6a2035abc90a>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# # Task - 3 - Outlier Detection:

# %% [markdown]
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.

# %%
# Calculate IQR for Composite Score and GDP per capita
Q1_composite = sac_dataset['Composite Score'].quantile(0.25)
Q3_composite = sac_dataset['Composite Score'].quantile(0.75)
IQR_composite = Q3_composite - Q1_composite
lower_bound_composite = Q1_composite - 1.5 * IQR_composite
upper_bound_composite = Q3_composite + 1.5 * IQR_composite

Q1_gdp = sac_dataset['Log GDP per capita'].quantile(0.25)
Q3_gdp = sac_dataset['Log GDP per capita'].quantile(0.75)
IQR_gdp = Q3_gdp - Q1_gdp
lower_bound_gdp = Q1_gdp - 1.5 * IQR_gdp
upper_bound_gdp = Q3_gdp + 1.5 * IQR_gdp

# Identify outliers for Composite Score and GDP per capita
outliers_composite = sac_dataset[(sac_dataset['Composite Score'] < lower_bound_composite) |
                                 (sac_dataset['Composite Score'] > upper_bound_composite)]

outliers_gdp = sac_dataset[(sac_dataset['Log GDP per capita'] < lower_bound_gdp) |
                           (sac_dataset['Log GDP per capita'] > upper_bound_gdp)]

# Combine outliers from both criteria
outliers = pd.concat([outliers_composite, outliers_gdp]).drop_duplicates()

# Display outliers
print("Outliers based on Composite Score and GDP per Capita:")
print(outliers[['Country name', 'Composite Score', 'Log GDP per capita']])
# Out:
# Outliers based on Composite Score and GDP per Capita:
#   Country name  Composite Score  Log GDP per capita
# 3    Sri Lanka           1.0739               1.361
# 5  Afghanistan           0.3238               0.628

# %% [markdown]
# 2. Define outliers using the 1.5 × IQR rule

# %%
# Calculate IQR for Composite Score and GDP per capita using the 1.5 * IQR rule
Q1_composite = sac_dataset['Composite Score'].quantile(0.25)
Q3_composite = sac_dataset['Composite Score'].quantile(0.75)
IQR_composite = Q3_composite - Q1_composite
lower_bound_composite = Q1_composite - 1.5 * IQR_composite
upper_bound_composite = Q3_composite + 1.5 * IQR_composite

Q1_gdp = sac_dataset['Log GDP per capita'].quantile(0.25)
Q3_gdp = sac_dataset['Log GDP per capita'].quantile(0.75)
IQR_gdp = Q3_gdp - Q1_gdp
lower_bound_gdp = Q1_gdp - 1.5 * IQR_gdp
upper_bound_gdp = Q3_gdp + 1.5 * IQR_gdp

# Identify outliers for Composite Score and GDP per capita based on the IQR rule
outliers_composite = sac_dataset[(sac_dataset['Composite Score'] < lower_bound_composite) |
                                 (sac_dataset['Composite Score'] > upper_bound_composite)]

outliers_gdp = sac_dataset[(sac_dataset['Log GDP per capita'] < lower_bound_gdp) |
                           (sac_dataset['Log GDP per capita'] > upper_bound_gdp)]

# Combine the outliers from both criteria
outliers = pd.concat([outliers_composite, outliers_gdp]).drop_duplicates()

# Display the outliers
print("Outliers based on 1.5 × IQR rule for Composite Score and GDP per Capita:")
print(outliers[['Country name', 'Composite Score', 'Log GDP per capita']])
# Out:
# Outliers based on 1.5 × IQR rule for Composite Score and GDP per Capita:
#   Country name  Composite Score  Log GDP per capita
# 3    Sri Lanka           1.0739               1.361
# 5  Afghanistan           0.3238               0.628

# %% [markdown]
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.

# %%
plt.figure(figsize=(10, 6))

# Plot all countries
plt.scatter(sac_dataset['Log GDP per capita'], sac_dataset['Composite Score'], color='blue', label='Countries')

# Highlight the outliers
plt.scatter(outliers['Log GDP per capita'], outliers['Composite Score'], color='red', label='Outliers')

# Annotate the outliers with their indices (Country names or indices)
for i, row in outliers.iterrows():
    plt.text(row['Log GDP per capita'], row['Composite Score'], f'{i}', fontsize=9, color='black', ha='center')

# Add labels and title
plt.xlabel('Log GDP per Capita')
plt.ylabel('Composite Score')
plt.title('Scatter Plot of GDP per Capita vs Composite Score (Outliers Highlighted)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %% [markdown]
# # Task - 4 - Exploring Trends Across Metrics:

# %% [markdown]
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.

# %%
# Calculate Pearson correlation between Composite Score and Freedom to Make Life Choices
correlation_freedom = sac_dataset['Composite Score'].corr(sac_dataset['Freedom to make life choices'])

# Calculate Pearson correlation between Composite Score and Generosity
correlation_generosity = sac_dataset['Composite Score'].corr(sac_dataset['Generosity'])

# Print the results
print(f"Pearson correlation between Composite Score and Freedom to Make Life Choices: {correlation_freedom}")
print(f"Pearson correlation between Composite Score and Generosity: {correlation_generosity}")
# Out:
# Pearson correlation between Composite Score and Freedom to Make Life Choices: 0.6983775101077063
# Pearson correlation between Composite Score and Generosity: 0.6062854440632626

# %% [markdown]
# 2. Create scatter plots with trendlines for these metrics against the Score.

# %%
sns.set(style="whitegrid")

# Create a figure and axes for the plots
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Scatter plot for 'Freedom to Make Life Choices' vs 'Composite Score'
sns.regplot(x='Freedom to make life choices', y='Composite Score', data=sac_dataset, ax=axes[0],
            scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
axes[0].set_title('Freedom to Make Life Choices vs Composite Score')
axes[0].set_xlabel('Freedom to Make Life Choices')
axes[0].set_ylabel('Composite Score')

# Scatter plot for 'Generosity' vs 'Composite Score'
sns.regplot(x='Generosity', y='Composite Score', data=sac_dataset, ax=axes[1],
            scatter_kws={'color': 'green'}, line_kws={'color': 'red'})
axes[1].set_title('Generosity vs Composite Score')
axes[1].set_xlabel('Generosity')
axes[1].set_ylabel('Composite Score')

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
# Calculate the Pearson correlation coefficients for the selected metrics
corr_freedom = sac_dataset['Freedom to make life choices'].corr(sac_dataset['Composite Score'])
corr_generosity = sac_dataset['Generosity'].corr(sac_dataset['Composite Score'])

# Display the correlation results
print(f"Correlation between 'Freedom to Make Life Choices' and 'Composite Score': {corr_freedom:.2f}")
print(f"Correlation between 'Generosity' and 'Composite Score': {corr_generosity:.2f}")
# Out:
# Correlation between 'Freedom to Make Life Choices' and 'Composite Score': 0.70
# Correlation between 'Generosity' and 'Composite Score': 0.61

# %% [markdown]
# Task - 5 - Gap Analysis:

# %% [markdown]
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.

# %%
# Add a new column 'GDP-Score Gap' to the dataset
sac_dataset['GDP-Score Gap'] = sac_dataset['Log GDP per capita'] - sac_dataset['Composite Score']

# Display the updated dataset with the new column
print(sac_dataset[['Country name', 'Log GDP per capita', 'Composite Score', 'GDP-Score Gap']].head())
# Out:
#   Country name  Log GDP per capita  Composite Score  GDP-Score Gap
# 0        Nepal               0.965           0.8159         0.1491
# 1     Pakistan               1.069           0.7039         0.3651
# 2        India               1.166           0.7874         0.3786
# 3    Sri Lanka               1.361           1.0739         0.2871
# 4   Bangladesh               1.122           0.6774         0.4446

# %% [markdown]
# 2. Rank the South Asian countries by this gap in both ascending and descending order.

# %%
# Rank the countries by 'GDP-Score Gap' in ascending and descending order
sac_dataset['Rank by GDP-Score Gap (Ascending)'] = sac_dataset['GDP-Score Gap'].rank(ascending=True, method='min')
sac_dataset['Rank by GDP-Score Gap (Descending)'] = sac_dataset['GDP-Score Gap'].rank(ascending=False, method='min')

# Sort the dataset by 'GDP-Score Gap' in both ascending and descending order
ranked_ascending = sac_dataset.sort_values(by='GDP-Score Gap', ascending=True)
ranked_descending = sac_dataset.sort_values(by='GDP-Score Gap', ascending=False)

# Display the ranked datasets
print("Ranking by GDP-Score Gap (Ascending Order):")
print(ranked_ascending[['Country name', 'GDP-Score Gap', 'Rank by GDP-Score Gap (Ascending)']])

print("\nRanking by GDP-Score Gap (Descending Order):")
print(ranked_descending[['Country name', 'GDP-Score Gap', 'Rank by GDP-Score Gap (Descending)']])
# Out:
# Ranking by GDP-Score Gap (Ascending Order):
#   Country name  GDP-Score Gap  Rank by GDP-Score Gap (Ascending)
# 0        Nepal         0.1491                                1.0
# 3    Sri Lanka         0.2871                                2.0
# 5  Afghanistan         0.3042                                3.0
# 1     Pakistan         0.3651                                4.0
# 2        India         0.3786                                5.0
# 4   Bangladesh         0.4446                                6.0
#
# Ranking by GDP-Score Gap (Descending Order):
#   Country name  GDP-Score Gap  Rank by GDP-Score Gap (Descending)
# 4   Bangladesh         0.4446                                 1.0
# 2        India         0.3786                                 2.0
# 1     Pakistan         0.3651                                 3.0
# 5  Afghanistan         0.3042                                 4.0
# 3    Sri Lanka         0.2871                                 5.0
# ...

# %% [markdown]
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.

# %%
# Get the top 3 countries with the largest positive and negative GDP-Score Gap
top_positive_gap = sac_dataset.nlargest(3, 'GDP-Score Gap')
top_negative_gap = sac_dataset.nsmallest(3, 'GDP-Score Gap')

# Combine the two datasets (top positive and negative gaps)
top_gaps = pd.concat([top_positive_gap, top_negative_gap])

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.barh(top_gaps['Country name'], top_gaps['GDP-Score Gap'], color=['green', 'red'] * 3)

# Adding titles and labels
plt.title('Top 3 Countries with Largest Positive and Negative GDP-Score Gaps', fontsize=14)
plt.xlabel('GDP-Score Gap', fontsize=12)
plt.ylabel('Country', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.
#
#
# Analyzing the Reasons Behind the GDP-Score Gaps in South Asian Countries
# The GDP-Score Gap is the difference between the GDP per capita of a country and its composite score (which includes factors like Social Support, Healthy Life Expectancy, and other socio-economic indicators). By analyzing the top positive and negative gaps, we can investigate the possible reasons behind these disparities and their broader implications for South Asian countries.
#
# Countries with Largest Positive Gaps (GDP > Score)
# Positive Gap Interpretation: Countries with a large positive GDP-Score Gap have high GDP per capita but relatively lower scores in terms of social support, health outcomes, or other social indicators. This suggests a disparity between economic wealth and the quality of life or well-being of their citizens.
# Possible Reasons:
# Economic Growth vs. Social Development:
# Countries with high GDP per capita but lower social support may have experienced rapid economic growth, but this growth has not been inclusive. Economic wealth may be concentrated in specific sectors or regions, while broader social development (healthcare, education, social security) has not kept pace.
# Income Inequality:
# A large GDP-Score Gap could also reflect significant income inequality, where wealth is distributed unequally. This disparity can lead to lower scores in indicators such as social support, healthy life expectancy, and education, as a large portion of the population may not benefit from the economic growth.
# Limited Access to Healthcare or Social Services:
# Countries with high economic wealth but poor social scores may not have effectively channeled their economic resources into healthcare or other public services. The gap indicates that while the country might be economically prosperous, its citizens may not have adequate access to essential services or benefits.
# Implications:
# Social Stability: The gap may lead to social unrest as citizens become disillusioned with the benefits of economic growth that do not translate into improved living conditions.
# Policy Focus: Governments in such countries may need to shift focus from mere economic growth to ensuring the equitable distribution of wealth and better investment in healthcare, education, and social welfare to improve overall well-being.
# Countries with Largest Negative Gaps (Score > GDP)
# Negative Gap Interpretation: Countries with a large negative GDP-Score Gap have relatively low GDP per capita but high social support, healthy life expectancy, and other indicators related to well-being. This suggests that these countries are performing better on human development measures than their economic output would suggest.
# Possible Reasons:
# Social Policies Focus:
# Countries with positive scores but low GDP per capita may have invested heavily in public welfare policies that prioritize the health and well-being of their citizens. They might not have the highest economic output, but they may provide robust social safety nets and universal healthcare, leading to better health outcomes and social support.
# Efficient Use of Limited Resources:
# Some countries with lower GDP may have managed to maximize the impact of their limited resources. For example, investing in affordable healthcare, ensuring access to basic needs, or having strong community networks could help these countries outperform expectations on socio-economic indicators.
# Social Cohesion and Support Systems:
# High social support could be a result of strong community networks, cultural cohesion, or a robust informal economy where individuals support one another in times of need, even without substantial national economic wealth.
# Implications:
# Sustainability of Development: These countries may face challenges in sustaining their high social scores without further economic development. While they have strong social systems, limited economic growth could undermine future improvements in healthcare, education, and infrastructure.
# Potential for Growth: With the right economic policies, these countries have the potential to build on their strong social foundations, creating a more balanced and sustainable development trajectory. Expanding economic opportunities could complement their existing social infrastructure.
# Broader Implications for South Asia
# Economic and Social Development Balance:
#
# In South Asia, balancing economic growth with social development is crucial. Countries need to ensure that economic progress translates into tangible improvements in health, education, and social support.
# Targeted Policies:
#
# Policymakers must address disparities by targeting both economic inequality and social development. This includes creating inclusive economic growth strategies that ensure all citizens benefit and investing in public welfare systems to maintain high scores in social support and health outcomes.
# International Aid and Partnerships:
#
# Countries with negative gaps may benefit from international partnerships focused on sustainable development. These countries can leverage their strong social foundations while seeking to boost their economic growth through foreign investments and trade.
# Equitable Growth:
#
# Countries with large positive gaps should focus on reducing inequality to prevent the negative social consequences of wealth concentration. Ensuring that the economic benefits of growth reach the broader population is key to improving social indicators.
# In summary, the GDP-Score Gap reflects the tension between economic output and social outcomes in South Asia. Addressing these gaps requires a multifaceted approach, focusing not only on boosting GDP but also on improving social welfare systems to ensure that economic growth benefits all citizens.

# %% [markdown]
# # 3.3 Problem - 3 - Comparative Analysis:

# %% [markdown]
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Sau

# %% [markdown]
# 1. Descriptive Statistics:
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
# • Which region has higher happiness Scores on average?

# %%
middle_east_countries = [
    "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
    "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar",
    "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"
]

# Filter the dataset for Middle Eastern countries
mec_dataset = dataset[dataset['Country name'].isin(middle_east_countries)].copy()

# Display the DataFrame
print("Middle Eastern Countries DataFrame:")
print(mec_dataset)

# Save the filtered dataset for future use
mec_dataset.to_csv('/content/middle_east_dataset.csv', index=False)
# Out:
# Middle Eastern Countries DataFrame:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %%
# Calculate mean and standard deviation for South Asia
south_asia_mean = sac_dataset['score'].mean()
south_asia_std = sac_dataset['score'].std()

# Calculate mean and standard deviation for Middle East
middle_east_mean = mec_dataset['score'].mean()
middle_east_std = mec_dataset['score'].std()

# Display the results
print("Descriptive Statistics:")
print(f"South Asia - Mean: {south_asia_mean:.2f}, Standard Deviation: {south_asia_std:.2f}")
print(f"Middle East - Mean: {middle_east_mean:.2f}, Standard Deviation: {middle_east_std:.2f}")

# Determine which region has higher happiness scores on average
if south_asia_mean > middle_east_mean:
    print("\nSouth Asia has higher happiness scores on average.")
elif south_asia_mean < middle_east_mean:
    print("\nThe Middle East has higher happiness scores on average.")
else:
    print("\nBoth regions have the same average happiness scores.")
# Out:
# Descriptive Statistics:
# South Asia - Mean: 3.90, Standard Deviation: 1.18
# Middle East - Mean: 5.41, Standard Deviation: 1.57
#
# The Middle East has higher happiness scores on average.

# %% [markdown]
# 3. Metric Comparisons:
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.
# • Which metrics show the largest disparity between the two regions?

# %%
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']

# South Asia means
south_asia_means = sac_dataset[metrics].mean()

# Middle East means
middle_east_means = mec_dataset[metrics].mean()

# Plotting grouped bar charts
x = np.arange(len(metrics))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width/2, south_asia_means, width, label='South Asia', color='skyblue')
bars2 = ax.bar(x + width/2, middle_east_means, width, label='Middle East', color='orange')

# Add text for labels, title, and axes ticks
ax.set_xlabel('Metrics')
ax.set_ylabel('Average Value')
ax.set_title('Comparison of Key Metrics between South Asia and Middle East')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Add data labels above bars
for bars in [bars1, bars2]:
    ax.bar_label(bars, fmt='%.2f', padding=3)

# Display the plot
plt.tight_layout()
plt.show()

# Calculate the largest disparity
disparities = abs(south_asia_means - middle_east_means)
largest_disparity_metric = disparities.idxmax()
largest_disparity_value = disparities.max()

# Display the metric with the largest disparity
print("\nMetric with the largest disparity between South Asia and Middle East:")
print(f"{largest_disparity_metric}: {largest_disparity_value:.2f}")
# Out:
# Metric with the largest disparity between South Asia and Middle East:
# Social support: 0.54

# %% [markdown]
# #4. Happiness Disparity:
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
# • Which region has greater variability in happiness?

# %%
# Descriptive Statistics for South Asia and Middle East

# Compute descriptive statistics for Score (mean, standard deviation, range, and coefficient of variation) for South Asia
sac_score_stats = {
    "Mean": sac_dataset['score'].mean(),
    "Standard Deviation": sac_dataset['score'].std(),
    "Range": sac_dataset['score'].max() - sac_dataset['score'].min(),
    "Coefficient of Variation": sac_dataset['score'].std() / sac_dataset['score'].mean()
}

# Compute descriptive statistics for Score (mean, standard deviation, range, and coefficient of variation) for Middle East
mec_score_stats = {
    "Mean": mec_dataset['score'].mean(),
    "Standard Deviation": mec_dataset['score'].std(),
    "Range": mec_dataset['score'].max() - mec_dataset['score'].min(),
    "Coefficient of Variation": mec_dataset['score'].std() / mec_dataset['score'].mean()
}

# Print the results
print("South Asia Score Statistics:")
for key, value in sac_score_stats.items():
    print(f"{key}: {value:.2f}")

print("\nMiddle East Score Statistics:")
for key, value in mec_score_stats.items():
    print(f"{key}: {value:.2f}")

# Determine which region has greater variability in happiness
if sac_score_stats["Coefficient of Variation"] > mec_score_stats["Coefficient of Variation"]:
    print("\nSouth Asia has greater variability in happiness.")
elif sac_score_stats["Coefficient of Variation"] < mec_score_stats["Coefficient of Variation"]:
    print("\nMiddle East has greater variability in happiness.")
else:
    print("\nBoth regions have equal variability in happiness.")
# Out:
# South Asia Score Statistics:
# Mean: 3.90
# Standard Deviation: 1.18
# Range: 3.44
# Coefficient of Variation: 0.30
#
# Middle East Score Statistics:
# Mean: 5.41
# Standard Deviation: 1.57
# Range: 4.63
# Coefficient of Variation: 0.29
#
# South Asia has greater variability in happiness.

# %% [markdown]
# 5. Correlation Analysis:
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
# • Create scatter plots to visualize and interpret the relationships.

# %%
# Calculate correlation of 'score' with 'Freedom to Make Life Choices' and 'Generosity' for both regions
sac_corr_freedom = sac_dataset['score'].corr(sac_dataset['Freedom to make life choices'])
sac_corr_generosity = sac_dataset['score'].corr(sac_dataset['Generosity'])

mec_corr_freedom = mec_dataset['score'].corr(mec_dataset['Freedom to make life choices'])
mec_corr_generosity = mec_dataset['score'].corr(mec_dataset['Generosity'])

print("South Asia Correlations:")
print(f"Freedom to Make Life Choices: {sac_corr_freedom:.2f}")
print(f"Generosity: {sac_corr_generosity:.2f}")

print("\nMiddle East Correlations:")
print(f"Freedom to Make Life Choices: {mec_corr_freedom:.2f}")
print(f"Generosity: {mec_corr_generosity:.2f}")

# Create scatter plots with trendlines
plt.figure(figsize=(14, 6))

# South Asia - Freedom to Make Life Choices vs Score
plt.subplot(2, 2, 1)
sns.regplot(x='Freedom to make life choices', y='score', data=sac_dataset, color='blue')
plt.title('South Asia: Freedom to Make Life Choices vs Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')

# South Asia - Generosity vs Score
plt.subplot(2, 2, 2)
sns.regplot(x='Generosity', y='score', data=sac_dataset, color='green')
plt.title('South Asia: Generosity vs Score')
plt.xlabel('Generosity')
plt.ylabel('Score')

# Middle East - Freedom to Make Life Choices vs Score
plt.subplot(2, 2, 3)
sns.regplot(x='Freedom to make life choices', y='score', data=mec_dataset, color='blue')
plt.title('Middle East: Freedom to Make Life Choices vs Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')

# Middle East - Generosity vs Score
plt.subplot(2, 2, 4)
sns.regplot(x='Generosity', y='score', data=mec_dataset, color='green')
plt.title('Middle East: Generosity vs Score')
plt.xlabel('Generosity')
plt.ylabel('Score')

plt.tight_layout()
plt.show()
# Out:
# South Asia Correlations:
# Freedom to Make Life Choices: 0.80
# Generosity: 0.87
#
# Middle East Correlations:
# Freedom to Make Life Choices: 0.86
# Generosity: 0.63

# %% [markdown]
# 6. Outlier Detection:
# • Identify outlier countries in both regions based on Score and GDP per Capita.
# • Plot these outliers and discuss their implications.

# %%
# Transform GDP per capita to Log GDP per capita
sac_dataset['Log GDP per capita'] = np.log(sac_dataset['Log GDP per capita'])
mec_dataset['Log GDP per capita'] = np.log(mec_dataset['Log GDP per capita'])

# Function to detect outliers using IQR
def detect_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] < lower_bound) | (df[column] > upper_bound)]

# Detect outliers in Score and Log GDP per capita
sac_outliers_score = detect_outliers(sac_dataset, 'score')
sac_outliers_log_gdp = detect_outliers(sac_dataset, 'Log GDP per capita')

mec_outliers_score = detect_outliers(mec_dataset, 'score')
mec_outliers_log_gdp = detect_outliers(mec_dataset, 'Log GDP per capita')

# Combine all outliers for each region
sac_outliers = pd.concat([sac_outliers_score, sac_outliers_log_gdp]).drop_duplicates()
mec_outliers = pd.concat([mec_outliers_score, mec_outliers_log_gdp]).drop_duplicates()

# Visualization of Outliers
plt.figure(figsize=(14, 6))

# South Asia - Score vs Log GDP per Capita
plt.subplot(1, 2, 1)
sns.scatterplot(x='Log GDP per capita', y='score', data=sac_dataset, label='South Asia', color='blue')
sns.scatterplot(x='Log GDP per capita', y='score', data=sac_outliers, label='Outliers', color='red', marker='o')
plt.title('South Asia: Outliers in Score and Log GDP per Capita')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')

# Middle East - Score vs Log GDP per Capita
plt.subplot(1, 2, 2)
sns.scatterplot(x='Log GDP per capita', y='score', data=mec_dataset, label='Middle East', color='green')
sns.scatterplot(x='Log GDP per capita', y='score', data=mec_outliers, label='Outliers', color='red', marker='o')
plt.title('Middle East: Outliers in Score and Log GDP per Capita')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')

plt.tight_layout()
plt.legend()
plt.show()

# Print outlier countries
print("South Asia Outliers:")
print(sac_outliers[['Country name', 'score', 'Log GDP per capita', 'Log GDP per capita']])

print("\nMiddle East Outliers:")
print(mec_outliers[['Country name', 'score', 'Log GDP per capita', 'Log GDP per capita']])
# Out:
# South Asia Outliers:
#   Country name  score  Log GDP per capita  Log GDP per capita
# 5  Afghanistan  1.721           -0.465215           -0.465215
#
# Middle East Outliers:
#     Country name  score  Log GDP per capita  Log GDP per capita
# 132        Yemen  3.561           -0.398986           -0.398986

# %% [markdown]
# 7. Visualization:
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
# Add a region column for comparison
sac_dataset['Region'] = 'South Asia'
mec_dataset['Region'] = 'Middle East'

# Combine datasets
combined_dataset = pd.concat([sac_dataset, mec_dataset])

# Visualization: Boxplots for Score by Region
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='score', data=combined_dataset, palette='Set2')

# Add title and labels
plt.title('Comparison of Score Distribution: South Asia vs Middle East', fontsize=14)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.show()
# Out:
# <ipython-input-35-6f8a914fb267>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Region', y='score', data=combined_dataset, palette='Set2')
